# %% [markdown]
# # Characteristics of Businesses

# %%
import requests
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
pd.set_option('display.max_rows', None)
pd.reset_option('display.max_rows', None)

# %% [markdown]
# ### Step #1
# Requested an individual API key from the website in order to request the data and URLs. Next, I requested individual columns I believed would be useful in my investigation on both a state level and a national US level. I stored the requested data in two json files with their respective information.

# %%
apikey = 'cabb73d5e421501e2701babc11c42a974c0e6e99'

# Get data for both state and US

business_nation = requests.get(f'http://api.census.gov/data/2018/abscb?get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,BUSCHAR,BUSCHAR_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,FIRMPDEMP,RCPPDEMP,EMP,PAYANN&for=us:*&key={apikey}')
print(business_nation)
business_state = requests.get(f'http://api.census.gov/data/2018/abscb?get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,BUSCHAR,BUSCHAR_LABEL,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,FIRMPDEMP,RCPPDEMP,EMP,PAYANN&for=state:*&key={apikey}')
print(business_state)

business_nation = business_nation.json()
business_nation = json.dumps(business_nation)

business_state = business_state.json()
business_state = json.dumps(business_state)
# Out:
# <Response [200]>
# <Response [200]>

# %% [markdown]
# ### Step #2
# Read in both the state and US json files to further clean and organize. Began the cleaning process by dropping unwanted columns that my group deemed unnecessary for the research. We decided to focus on the industries on each level and the characteristics that describe them.

# %%
# Find data on the US level
nation = pd.read_json(business_nation)

headers = nation.iloc[0]
bus = pd.DataFrame(nation.values[1:], columns=headers)

# Remove unwanted columns
bus = bus.drop(columns =['GEO_ID', 'NAICS2017', 'SEX', 'ETH_GROUP', 'RACE_GROUP', 'RACE_GROUP_LABEL', 'BUSCHAR', 'us'])
bus
# Out:
# 0              NAME            NAICS2017_LABEL      BUSCHAR_LABEL  \
# 0     United States      Total for all sectors          All firms
# 1     United States      Total for all sectors           1 person
# 2     United States      Total for all sectors      2 to 4 people
# 3     United States      Total for all sectors     5 to 10 people
# 4     United States      Total for all sectors  11 or more people
# ...             ...                        ...                ...
# 4298  United States  Industries not classified      2 to 4 people
# 4299  United States  Industries not classified    Total reporting
# 4300  United States  Industries not classified          All firms
# 4301  United States  Industries not classified      2 to 4 people
# 4302  United States  Industries not classified    Total reporting
#
# 0               SEX_LABEL                ETH_GROUP_LABEL FIRMPDEMP  \
# 0                   Total                          Total   5722142
# 1                   Total                          Total   1628501
# 2                   Total                          Total   1024784
# 3                   Total                          Total     49436
# 4                   Total                          Total     31846
# ...                   ...                            ...       ...
# 4298  Equally male/female                       Hispanic         0
# 4299  Equally male/female                       Hispanic         0
# 4300                Total  Equally Hispanic/non-Hispanic         0
# 4301                Total  Equally Hispanic/non-Hispanic         0
# 4302                Total  Equally Hispanic/non-Hispanic         0
#
# 0        RCPPDEMP        EMP      PAYANN
# 0     38405539368  128196406  6937240308
# 1      2270021185   10991334   454218390
# 2      2462681905   11240900   478308387
# 3       413777541    1423837    75150602
# 4      6023549720   13448854   986906070
# ...           ...        ...         ...
# 4298            0          0           0
# 4299            0          0           0
# 4300            0          0           0
# 4301            0          0           0
# 4302            0          0           0
#
# [4303 rows x 9 columns]

# %%
#find data on the state level
state = pd.read_json(business_state)

headers = state.iloc[0]
bstate = pd.DataFrame(state.values[1:], columns=headers)

#remove unwanted columns
bstate = bstate.drop(columns =['GEO_ID', 'NAICS2017', 'SEX', 'ETH_GROUP', 'RACE_GROUP', 'RACE_GROUP_LABEL', 'BUSCHAR', 'state'])
bstate
# Out:
# 0           NAME        NAICS2017_LABEL             BUSCHAR_LABEL SEX_LABEL  \
# 0    Mississippi  Total for all sectors                 All firms     Total
# 1    Mississippi  Total for all sectors                  1 person     Total
# 2    Mississippi  Total for all sectors             2 to 4 people     Total
# 3    Mississippi  Total for all sectors            5 to 10 people     Total
# 4    Mississippi  Total for all sectors         11 or more people     Total
# ..           ...                    ...                       ...       ...
# 403    Minnesota  Total for all sectors            5 to 10 people     Total
# 404    Minnesota  Total for all sectors         11 or more people     Total
# 405    Minnesota  Total for all sectors  Unknown number of owners     Total
# 406    Minnesota  Total for all sectors           Total reporting     Total
# 407    Minnesota  Total for all sectors         Item not reported     Total
#
# 0   ETH_GROUP_LABEL FIRMPDEMP RCPPDEMP      EMP    PAYANN
# 0             Total     40856        0   920447  34137231
# 1             Total     10704        0    80964   2835519
# 2             Total      5956        0    59086   2031186
# 3             Total       360        0    13497    618245
# 4             Total       604        0   106361   4807141
# ..              ...       ...      ...      ...       ...
# 403           Total      1286        0    25264   1679605
# 404           Total      1475        0   327504  23461108
# 405           Total      1095        0   390188  28138080
# 406           Total     61423        0  1183664  71702040
# 407           Total      2766        0   175844  11299255
#
# [408 rows x 9 columns]

# %% [markdown]
# ### Step #3
# Renamed columns from both tables in order to read the data better for interpretation.

# %%
# rename column names to make it easier to read
bus.rename(columns={'NAME': 'Country',
                    'NAICS2017_LABEL':'Industry',
                    'BUSCHAR_LABEL': 'BusinessCharacteristic',
                    'SEX_LABEL':'Sex',
                    'ETH_GROUP_LABEL':'Ethnicity',
                    'FIRMPDEMP':'EmployerFirms',
                    'RCPPDEMP':'SalesRevenue',
                    'EMP':'Employees',
                    'PAYANN':'Payroll'}, inplace=True)

bus.head()
# Out:
# 0        Country               Industry BusinessCharacteristic    Sex  \
# 0  United States  Total for all sectors              All firms  Total
# 1  United States  Total for all sectors               1 person  Total
# 2  United States  Total for all sectors          2 to 4 people  Total
# 3  United States  Total for all sectors         5 to 10 people  Total
# 4  United States  Total for all sectors      11 or more people  Total
#
# 0 Ethnicity EmployerFirms SalesRevenue  Employees     Payroll
# 0     Total       5722142  38405539368  128196406  6937240308
# 1     Total       1628501   2270021185   10991334   454218390
# 2     Total       1024784   2462681905   11240900   478308387
# 3     Total         49436    413777541    1423837    75150602
# 4     Total         31846   6023549720   13448854   986906070

# %%
# rename column names to make it easier to read
bstate.rename(columns={'NAME':'State',
                    'NAICS2017_LABEL':'Industry',
                    'BUSCHAR_LABEL': 'BusinessCharacteristic',
                    'SEX_LABEL':'Sex',
                    'ETH_GROUP_LABEL':'Ethnicity',
                    'FIRMPDEMP':'EmployerFirms',
                    'RCPPDEMP':'SalesRevenue',
                    'EMP':'Employees',
                    'PAYANN':'Payroll'}, inplace=True)

bstate.head()
# Out:
# 0        State               Industry BusinessCharacteristic    Sex Ethnicity  \
# 0  Mississippi  Total for all sectors              All firms  Total     Total
# 1  Mississippi  Total for all sectors               1 person  Total     Total
# 2  Mississippi  Total for all sectors          2 to 4 people  Total     Total
# 3  Mississippi  Total for all sectors         5 to 10 people  Total     Total
# 4  Mississippi  Total for all sectors      11 or more people  Total     Total
#
# 0 EmployerFirms SalesRevenue Employees   Payroll
# 0         40856            0    920447  34137231
# 1         10704            0     80964   2835519
# 2          5956            0     59086   2031186
# 3           360            0     13497    618245
# 4           604            0    106361   4807141

# %% [markdown]
# ### Step #4
# Changed the data types of several columns from objects to floats for readability and in order to aggregate the columns later for visualizations.

# %%
# Change some objects into numeric data that can be calculated
columns_float = ['EmployerFirms', 'SalesRevenue', 'Employees', 'Payroll']

for column in columns_float:
    bus[column]=bus[column].astype('float')

bus.head(50)
# Out:
# 0         Country               Industry    BusinessCharacteristic  \
# 0   United States  Total for all sectors                 All firms
# 1   United States  Total for all sectors                  1 person
# 2   United States  Total for all sectors             2 to 4 people
# 3   United States  Total for all sectors            5 to 10 people
# 4   United States  Total for all sectors         11 or more people
# 5   United States  Total for all sectors  Unknown number of owners
# 6   United States  Total for all sectors           Total reporting
# 7   United States  Total for all sectors         Item not reported
# 8   United States  Total for all sectors                 All firms
# 9   United States  Total for all sectors                  1 person
# 10  United States  Total for all sectors             2 to 4 people
# 11  United States  Total for all sectors            5 to 10 people
# 12  United States  Total for all sectors         11 or more people
# 13  United States  Total for all sectors  Unknown number of owners
# 14  United States  Total for all sectors           Total reporting
# 15  United States  Total for all sectors         Item not reported
# 16  United States  Total for all sectors                 All firms
# 17  United States  Total for all sectors                  1 person
# 18  United States  Total for all sectors             2 to 4 people
# 19  United States  Total for all sectors            5 to 10 people
# 20  United States  Total for all sectors         11 or more people
# 21  United States  Total for all sectors  Unknown number of owners
# 22  United States  Total for all sectors           Total reporting
# 23  United States  Total for all sectors         Item not reported
# 24  United States  Total for all sectors                 All firms
# 25  United States  Total for all sectors                  1 person
# 26  United States  Total for all sectors             2 to 4 people
# 27  United States  Total for all sectors            5 to 10 people
# 28  United States  Total for all sectors         11 or more people
# 29  United States  Total for all sectors  Unknown number of owners
# 30  United States  Total for all sectors           Total reporting
# 31  United States  Total for all sectors         Item not reported
# 32  United States  Total for all sectors                 All firms
# 33  United States  Total for all sectors                  1 person
# 34  United States  Total for all sectors             2 to 4 people
# 35  United States  Total for all sectors            5 to 10 people
# 36  United States  Total for all sectors         11 or more people
# 37  United States  Total for all sectors  Unknown number of owners
# 38  United States  Total for all sectors           Total reporting
# 39  United States  Total for all sectors         Item not reported
# 40  United States  Total for all sectors                 All firms
# 41  United States  Total for all sectors                  1 person
# 42  United States  Total for all sectors             2 to 4 people
# 43  United States  Total for all sectors            5 to 10 people
# 44  United States  Total for all sectors  Unknown number of owners
# 45  United States  Total for all sectors           Total reporting
# 46  United States  Total for all sectors         Item not reported
# 47  United States  Total for all sectors                 All firms
# 48  United States  Total for all sectors                  1 person
# 49  United States  Total for all sectors             2 to 4 people
#
# 0                   Sex Ethnicity  EmployerFirms  SalesRevenue    Employees  \
# 0                 Total     Total      5722142.0  3.840554e+10  128196406.0
# 1                 Total     Total      1628501.0  2.270021e+09   10991334.0
# 2                 Total     Total      1024784.0  2.462682e+09   11240900.0
# 3                 Total     Total        49436.0  4.137775e+08    1423837.0
# 4                 Total     Total        31846.0  6.023550e+09   13448854.0
# 5                 Total     Total        21585.0  7.482372e+09   17527385.0
# 6                 Total     Total      2756150.0  1.865240e+10   54632311.0
# 7                 Total     Total       127395.0  2.951022e+09    7714221.0
# 8                Female     Total      1141410.0  1.776835e+09   10149257.0
# 9                Female     Total       416190.0  2.823855e+08    2150147.0
# 10               Female     Total       147870.0  2.674275e+08    1499541.0
# 11               Female     Total         6894.0  3.155573e+07     127916.0
# 12               Female     Total            0.0  0.000000e+00          0.0
# 13               Female     Total         1791.0  4.560223e+06      22714.0
# 14               Female     Total       574054.0  5.973220e+08    3834314.0
# 15               Female     Total        18103.0  1.429350e+07     110011.0
# 16                 Male     Total      3496959.0  1.124004e+10   45346405.0
# 17                 Male     Total      1206856.0  1.590189e+09    7930369.0
# 18                 Male     Total       463481.0  1.568831e+09    6201858.0
# 19                 Male     Total        37558.0  2.965782e+08     982630.0
# 20                 Male     Total         9630.0  1.127375e+08     376769.0
# 21                 Male     Total         8970.0  6.566743e+07     276244.0
# 22                 Male     Total      1726493.0  3.634003e+09   15767870.0
# 23                 Male     Total        58916.0  7.209661e+07     399840.0
# 24  Equally male/female     Total       860754.0  1.340608e+09    7970121.0
# 25  Equally male/female     Total         2409.0  2.063823e+06      11028.0
# 26  Equally male/female     Total       410872.0  4.712613e+08    3063894.0
# 27  Equally male/female     Total         3527.0  1.234168e+07      75964.0
# 28  Equally male/female     Total          395.0  3.354984e+06      11363.0
# 29  Equally male/female     Total          964.0  1.515907e+06      10488.0
# 30  Equally male/female     Total       418168.0  4.905377e+08    3172736.0
# 31  Equally male/female     Total        12243.0  1.077715e+07      81907.0
# 32                Total  Hispanic       331625.0  4.556447e+08    2972140.0
# 33                Total  Hispanic        99797.0  8.544297e+07     602073.0
# 34                Total  Hispanic        48602.0  7.705149e+07     482706.0
# 35                Total  Hispanic         1304.0  3.982941e+06      22941.0
# 36                Total  Hispanic          140.0  5.079310e+05       1483.0
# 37                Total  Hispanic            0.0  0.000000e+00          0.0
# 38                Total  Hispanic       150401.0  1.711175e+08    1125220.0
# 39                Total  Hispanic         5839.0  3.968589e+06      34739.0
# 40               Female  Hispanic        84496.0  9.110372e+07     722654.0
# 41               Female  Hispanic        29357.0  1.677526e+07     159987.0
# 42               Female  Hispanic         9371.0  1.663865e+07      94991.0
# 43               Female  Hispanic            0.0  0.000000e+00          0.0
# 44               Female  Hispanic            0.0  0.000000e+00          0.0
# 45               Female  Hispanic        39245.0  3.568136e+07     266313.0
# 46               Female  Hispanic         1474.0  6.001230e+05       8631.0
# 47                 Male  Hispanic       209426.0  3.257731e+08    1957790.0
# 48                 Male  Hispanic        70133.0  6.854016e+07     441371.0
# 49                 Male  Hispanic        22348.0  4.310893e+07     269538.0
#
# 0        Payroll
# 0   6.937240e+09
# 1   4.542184e+08
# 2   4.783084e+08
# 3   7.515060e+07
# 4   9.869061e+08
# 5   1.199174e+09
# 6   3.193758e+09
# 7   4.614945e+08
# 8   3.880852e+08
# 9   7.201726e+07
# 10  5.838778e+07
# 11  5.901975e+06
# 12  0.000000e+00
# 13  1.172943e+06
# 14  1.389713e+08
# 15  3.314287e+06
# 16  2.140502e+09
# 17  3.313863e+08
# 18  2.958325e+08
# 19  5.448055e+07
# 20  2.656228e+07
# 21  1.426694e+07
# 22  7.225285e+08
# 23  1.521477e+07
# 24  2.798530e+08
# 25  3.327590e+05
# 26  1.009346e+08
# 27  2.759520e+06
# 28  7.124160e+05
# 29  3.403320e+05
# 30  1.050796e+08
# 31  2.383057e+06
# 32  1.011033e+08
# 33  2.052716e+07
# 34  1.640475e+07
# 35  8.649860e+05
# 36  1.087670e+05
# 37  0.000000e+00
# 38  3.874059e+07
# 39  8.520700e+05
# 40  2.197568e+07
# 41  4.664338e+06
# 42  3.232247e+06
# 43  0.000000e+00
# 44  0.000000e+00
# 45  8.321142e+06
# 46  1.784860e+05
# 47  7.054344e+07
# 48  1.584499e+07
# 49  9.491830e+06

# %%
# Change some objects into numeric data that can be calculated on a state level

columns_float = ['EmployerFirms', 'SalesRevenue', 'Employees', 'Payroll']

for column in columns_float:
    bstate[column]=bstate[column].astype('float')

bstate
# Out:
# 0          State               Industry    BusinessCharacteristic    Sex  \
# 0    Mississippi  Total for all sectors                 All firms  Total
# 1    Mississippi  Total for all sectors                  1 person  Total
# 2    Mississippi  Total for all sectors             2 to 4 people  Total
# 3    Mississippi  Total for all sectors            5 to 10 people  Total
# 4    Mississippi  Total for all sectors         11 or more people  Total
# ..           ...                    ...                       ...    ...
# 403    Minnesota  Total for all sectors            5 to 10 people  Total
# 404    Minnesota  Total for all sectors         11 or more people  Total
# 405    Minnesota  Total for all sectors  Unknown number of owners  Total
# 406    Minnesota  Total for all sectors           Total reporting  Total
# 407    Minnesota  Total for all sectors         Item not reported  Total
#
# 0   Ethnicity  EmployerFirms  SalesRevenue  Employees     Payroll
# 0       Total        40856.0           0.0   920447.0  34137231.0
# 1       Total        10704.0           0.0    80964.0   2835519.0
# 2       Total         5956.0           0.0    59086.0   2031186.0
# 3       Total          360.0           0.0    13497.0    618245.0
# 4       Total          604.0           0.0   106361.0   4807141.0
# ..        ...            ...           ...        ...         ...
# 403     Total         1286.0           0.0    25264.0   1679605.0
# 404     Total         1475.0           0.0   327504.0  23461108.0
# 405     Total         1095.0           0.0   390188.0  28138080.0
# 406     Total        61423.0           0.0  1183664.0  71702040.0
# 407     Total         2766.0           0.0   175844.0  11299255.0
#
# [408 rows x 9 columns]

# %% [markdown]
# ### Step #5
# Created tables to individually work from when creating visualizaitons. Tables that were created were ones for industries, business characteristics, and employee payrolls based on sex.

# %%
# table to calculate number of employees and firms in the US per industry
industry = bus[['Industry', 'Employees', 'EmployerFirms']]

# leave out total for industries
industry = industry[(industry['Industry'] !='Total for all sectors')]

# group by industry type and the number of emplyees/firms
industry = industry.groupby(['Industry'], as_index = False)['Employees', 'EmployerFirms'].sum()

#Sort by the number of employees for each industry
industry.sort_values(by ='Employees', ascending = False, inplace = True)

industry.head(20)
# Out:
# C:\Users\cheyp\AppData\Local\Temp\ipykernel_14796\3176164141.py:8: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   industry = industry.groupby(['Industry'], as_index = False)['Employees', 'EmployerFirms'].sum()
# 0                                            Industry    Employees  \
# 0                     Accommodation and food services  134697571.0
# 7                   Health care and social assistance  112694050.0
# 16                                       Retail trade   98969057.0
# 1   Administrative and support and waste managemen...   84757668.0
# 4                                        Construction   81062707.0
# 14   Professional, scientific, and technical services   78225356.0
# 11                                      Manufacturing   76654930.0
# 19                                    Wholesale trade   50661504.0
# 13      Other services (except public administration)   31939012.0
# 6                               Finance and insurance   31097753.0
# 17                     Transportation and warehousing   29174184.0
# 15                 Real estate and rental and leasing   19270936.0
# 9                                         Information   16712091.0
# 3                 Arts, entertainment, and recreation   15404582.0
# 5                                Educational services   11828599.0
# 10            Management of companies and enterprises   11779208.0
# 2          Agriculture, forestry, fishing and hunting    7506623.0
# 12      Mining, quarrying, and oil and gas extraction    3466884.0
# 18                                          Utilities    1914686.0
# 8                           Industries not classified    1071188.0
#
# 0   EmployerFirms
# 0       6733782.0
# 7       8503018.0
# 16      8486970.0
# 1       4744003.0
# 4      10127748.0
# 14     12127831.0
# 11      3249778.0
# 19      4079581.0
# 13      5410230.0
# 6       3285003.0
# 17      2368296.0
# 15      4248991.0
# 9        947951.0
# 3       1476187.0
# 5        908415.0
# 10       202448.0
# 2        330115.0
# 12       222737.0
# 18        32145.0
# 8        240128.0

# %%
# table to calculate total number of employers in all industries per business characteristic
buschar = bus[['BusinessCharacteristic', 'Industry', 'EmployerFirms']]

# Only need the total for industries
buschar = buschar[(buschar['Industry'] =='Total for all sectors')]

# Filter out the unnecessary values
buschar = buschar[(buschar['BusinessCharacteristic'] != 'All firms') & (buschar['BusinessCharacteristic'] != 'Total reporting') & (buschar['BusinessCharacteristic'] != 'Item not reported')]

# group by both the business and industry type and get the sum of firms for each characteristic
buschar = buschar.groupby(['BusinessCharacteristic', 'Industry'], as_index = False)['EmployerFirms'].sum()

# sort by the number of employers to see which business types have the most employers
buschar.sort_values(by='EmployerFirms', ascending = False, inplace = True)

# renamed the columns to show further detail
buschar.rename(columns={'EmployerFirms': 'Total Employers',
                        'BusinessCharacteristic' : 'Number of Owners'}, inplace=True)

buschar.head(20)
# Out:
# 0          Number of Owners               Industry  Total Employers
# 0                  1 person  Total for all sectors       11396114.0
# 2             2 to 4 people  Total for all sectors        7144930.0
# 3            5 to 10 people  Total for all sectors         336087.0
# 1         11 or more people  Total for all sectors          92980.0
# 4  Unknown number of owners  Total for all sectors          88677.0

# %%
# table to see the number of employees and their total payrolls based on sex
payroll = bus[['Industry','Sex','Employees','Payroll']]

# Excluded the total industry value as it greatly skews the data for visualizations.
payroll = payroll[(payroll['Industry'] !='Total for all sectors')]

# Filtered out the data so that it would only show employees that are either male or female.
payroll = payroll[(payroll['Sex'] =='Female')|(payroll['Sex'] =='Male')]

# Grouped the data based on industry and sex
payroll = payroll.groupby(['Industry','Sex'], as_index = False).sum()

payroll.head(70)
# Out:
# 0                                            Industry     Sex   Employees  \
# 0                     Accommodation and food services  Female   7984887.0
# 1                     Accommodation and food services    Male  36704039.0
# 2   Administrative and support and waste managemen...  Female   5983489.0
# 3   Administrative and support and waste managemen...    Male  22553209.0
# 4          Agriculture, forestry, fishing and hunting  Female     96766.0
# 5          Agriculture, forestry, fishing and hunting    Male   2690129.0
# 6                 Arts, entertainment, and recreation  Female    734371.0
# 7                 Arts, entertainment, and recreation    Male   3788818.0
# 8                                        Construction  Female   3553394.0
# 9                                        Construction    Male  26256504.0
# 10                               Educational services  Female   1302763.0
# 11                               Educational services    Male   1364091.0
# 12                              Finance and insurance  Female   1002126.0
# 13                              Finance and insurance    Male   6605182.0
# 14                  Health care and social assistance  Female  10648248.0
# 15                  Health care and social assistance    Male  23323448.0
# 16                          Industries not classified  Female     47727.0
# 17                          Industries not classified    Male    199474.0
# 18                                        Information  Female    474573.0
# 19                                        Information    Male   3702177.0
# 20            Management of companies and enterprises  Female    210696.0
# 21            Management of companies and enterprises    Male   1775861.0
# 22                                      Manufacturing  Female   3023508.0
# 23                                      Manufacturing    Male  20905028.0
# 24      Mining, quarrying, and oil and gas extraction  Female     82794.0
# 25      Mining, quarrying, and oil and gas extraction    Male    902252.0
# 26      Other services (except public administration)  Female   3059244.0
# 27      Other services (except public administration)    Male   7612844.0
# 28   Professional, scientific, and technical services  Female   5664423.0
# 29   Professional, scientific, and technical services    Male  21575054.0
# 30                 Real estate and rental and leasing  Female   1184685.0
# 31                 Real estate and rental and leasing    Male   5329576.0
# 32                                       Retail trade  Female   4578826.0
# 33                                       Retail trade    Male  23065819.0
# 34                     Transportation and warehousing  Female   1145564.0
# 35                     Transportation and warehousing    Male   7375208.0
# 36                                          Utilities  Female      8674.0
# 37                                          Utilities    Male    155100.0
# 38                                    Wholesale trade  Female   2585116.0
# 39                                    Wholesale trade    Male  14686272.0
#
# 0        Payroll
# 0   1.455353e+08
# 1   6.998373e+08
# 2   2.043906e+08
# 3   8.166381e+08
# 4   2.192090e+06
# 5   3.561906e+07
# 6   2.971785e+07
# 7   1.423660e+08
# 8   2.069642e+08
# 9   1.512943e+09
# 10  3.100611e+07
# 11  4.406916e+07
# 12  5.456456e+07
# 13  5.818441e+08
# 14  3.469799e+08
# 15  1.094001e+09
# 16  5.649850e+05
# 17  2.776217e+06
# 18  2.886285e+07
# 19  3.110883e+08
# 20  1.632584e+07
# 21  1.471049e+08
# 22  1.365041e+08
# 23  1.040073e+09
# 24  6.235493e+06
# 25  6.972745e+07
# 26  7.626324e+07
# 27  2.674913e+08
# 28  3.276643e+08
# 29  1.579394e+09
# 30  5.192774e+07
# 31  2.556415e+08
# 32  1.274356e+08
# 33  8.127863e+08
# 34  4.706464e+07
# 35  3.405112e+08
# 36  5.698500e+05
# 37  1.200360e+07
# 38  1.504495e+08
# 39  9.225256e+08

# %% [markdown]
# ## Visualizations

# %%
plt.figure(figsize = (20, 10))

plt.barh(y = industry['Industry'], width = industry['Employees'], color = 'steelblue');

plt.title('Total Number of Employees per Industry in the US', size = 16)
plt.ylabel('Industry Type', size = 13)
plt.xlabel('Total of Employees', size = 13);

# %% [markdown]
# For my visualizations, I decided to focus on businesses and industries on the national US level rather than by state. The first visualization for the business characteristics is one that shows the amount of employees for each industry sector. As you can see, there are abundantly more employees in the accommodation and food services industry with health care/social social assistance and retail trade not far behind. This makes sense as these industries generally need more employees because they assist or help other people/customers.

# %%
plt.figure(figsize = (12, 6))

plt.bar(x = buschar['Number of Owners'], height = buschar['Total Employers'], color = 'mediumseagreen');

plt.title('Total Number of Business Owners per Employer Firms in the US', size = 16)
plt.xlabel('Number of Owners per Business', size = 13)
plt.ylabel('Total of Employer Firms', size = 13);

# %% [markdown]
# The next visualization demonstrates the popularity for a certain number of business owners per business. According to the graph, businesses in the US typically tend to have one business owner with two to four business owners being the next popular amount. If we go by the graph, it is very unlikely that businesses will have more than four owners per one business.

# %%
f, ax = plt.subplots(figsize=(10, 8))

sns.set_theme(style = "whitegrid")
sns.scatterplot(data = payroll, x = 'Payroll', y = 'Employees', hue = 'Sex', palette = 'viridis');
ax.set_title('Positive Correlation between the Number of Employees and Payroll Total', size = 15)
ax.set_xlabel('Payroll', size = 12) 
ax.set_ylabel('Number of Employees', size = 12);

# %% [markdown]
# For this scatterplot graph, I decided to focus on the payroll for the amount of amployees based on sex per industry. As you can see, there is a strong positive correlation between the amount of employees and the payroll total. This makes sense as the total of the employees payroll increases when the amount of employees increases. However, what is surprising is the drastic difference between the total payroll for males and females. To find out why there would be such a difference, I calculated the amount of males and females in each industry to better understand why males would have a pattern of such higher payrolls. What I found in the next stacked bar graph was that there tended to be a lot more males in almost all of the inndustries. With the highest amount of females being in the healthcare and social assistance industry. The only industry where the amount of males and females seemed to be equal was the education industry. With this knowledge, it can be easy to deduce that the vast difference between payrolls could be due to the amount of employees for the sexes. However, there could be another underlying reason that was not reported in the APIs, like females being paid less than males for instance. But that would be an inference based on guessed reasoning.

# %%
MFTable = pd.pivot_table(payroll, index=['Industry'], columns=['Sex'], values=['Employees'], aggfunc = sum)
MFTable.columns = ['_'.join(str(s).strip() for s in col if s) for col in MFTable.columns]
MFTable = MFTable.rename(columns={'Employees_Female': 'Female',
                                  'Employees_Male' : 'Male'});

MFTable.reset_index(inplace = True)

MFTable['Total'] = MFTable.sum(axis = 1)
MFTable = MFTable.sort_values(by = 'Total', ascending = False);

industry_stacked_bar_vals = MFTable.drop('Total', axis = 1);

sns.set_theme(style = "whitegrid")
industry_stacked_bar_vals.set_index('Industry').plot(kind = 'barh', stacked = True, color = ['steelblue', 'mediumseagreen'])
plt.title('Total Number of Male and Female Employees per Industry', fontsize = 18)
plt.ylabel('Industry', fontsize = 12)
plt.xlabel('Employee Total', fontsize = 12);
# Out:
# C:\Users\cheyp\AppData\Local\Temp\ipykernel_14796\1333570187.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   MFTable['Total'] = MFTable.sum(axis = 1)

# %%
indpayroll = pd.pivot_table(payroll, index=['Industry'], columns=['Sex'], values=['Payroll'], aggfunc = sum)
indpayroll.columns = ['_'.join(str(s).strip() for s in col if s) for col in indpayroll.columns]
indpayroll = indpayroll.rename(columns={'Payroll_Female': 'Female',
                                  'Payroll_Male' : 'Male'});

indpayroll.reset_index(inplace = True)

indpayroll['Total'] = indpayroll.sum(axis = 1)
indpayroll = indpayroll.sort_values(by = 'Total', ascending = False);

payroll_stacked_bar_vals = indpayroll.drop('Total', axis = 1);

sns.set_theme(style = "whitegrid")
payroll_stacked_bar_vals.set_index('Industry').plot(kind = 'barh', stacked = True, color = ['steelblue', 'mediumseagreen'])
plt.title('Payroll Total for Male and Female Employees in each Industry', fontsize = 18)
plt.ylabel('Industry', fontsize = 12)
plt.xlabel('Payroll Total', fontsize = 12);
# Out:
# C:\Users\cheyp\AppData\Local\Temp\ipykernel_14796\3411557977.py:8: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   indpayroll['Total'] = indpayroll.sum(axis = 1)
